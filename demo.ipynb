# %% [markdown]
# # Book to demo integrating puzzles etc

# %%
import sys; sys.path.append('.scripts')
from elements import button
from jupyterquiz import display_quiz, GITHUB_REPO_PATH
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 3
#       1 import sys; sys.path.append('.scripts')
#       2 from elements import button
# ----> 3 from jupyterquiz import display_quiz, GITHUB_REPO_PATH
#
# ImportError: cannot import name 'GITHUB_REPO_PATH' from 'jupyterquiz' (/home/mike/Documents/Teaching/UoNPhysicsCoding/demo_yr1/.venv/lib/python3.14/site-packages/jupyterquiz/__init__.py)

# %%
button("Open Rearrange Exercise in Browser", "rearrange_problem.html")
# Out:
#     <a href="https://uonphysicscoding.github.io/exercises/rearrange_problem.html" target="_blank" style="
#         display: inline-block;
#         padding: 12px 24px;
#         background: linear-gradient(135deg, #007bff, #0056b3);
#         color: white;
#         text-decoration: none;
#         border-radius: 8px;
#         box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);
#         font-weight: bold;
#         font-family: sans-serif;
#     ">
#         Open Rearrange Exercise in Browser
#     </a>

# %%
button("Open Toggle Exercise in Browser", "toggle_problem.html")
# Out:
#     <a href="https://uonphysicscoding.github.io/exercises/toggle_problem.html" target="_blank" style="
#         display: inline-block;
#         padding: 12px 24px;
#         background: linear-gradient(135deg, #007bff, #0056b3);
#         color: white;
#         text-decoration: none;
#         border-radius: 8px;
#         box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);
#         font-weight: bold;
#         font-family: sans-serif;
#     ">
#         Open Toggle Exercise in Browser
#     </a>

# %%
display_quiz(GITHUB_REPO_PATH + "quiz1.json")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 display_quiz(GITHUB_REPO_PATH + "quiz1.json")
#
# NameError: name 'GITHUB_REPO_PATH' is not defined
