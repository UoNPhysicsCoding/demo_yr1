# %% [markdown]
# # Book to demo integrating puzzles etc

# %%
from elements import *
from jupyterquiz import display_quiz

# %%
button("Open Rearrange Exercise in Browser", "rearrange_problem.html")
# Out:
#     <a href="https://uonphysicscoding.github.io/exercises/rearrange_problem.html" target="_blank" style="
#         display: inline-block;
#         padding: 12px 24px;
#         background: linear-gradient(135deg, #007bff, #0056b3);
#         color: white;
#         text-decoration: none;
#         border-radius: 8px;
#         box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);
#         font-weight: bold;
#         font-family: sans-serif;
#     ">
#         Open Rearrange Exercise in Browser
#     </a>

# %%
button("Open Toggle Exercise in Browser", "toggle_problem.html")
# Out:
#     <a href="https://uonphysicscoding.github.io/exercises/toggle_problem.html" target="_blank" style="
#         display: inline-block;
#         padding: 12px 24px;
#         background: linear-gradient(135deg, #007bff, #0056b3);
#         color: white;
#         text-decoration: none;
#         border-radius: 8px;
#         box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);
#         font-weight: bold;
#         font-family: sans-serif;
#     ">
#         Open Toggle Exercise in Browser
#     </a>

# %%
display_quiz(GITHUB_REPO_PATH + "exercises/quiz1.json")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 display_quiz(GITHUB_REPO_PATH + "exercises/quiz1.json")
#
# File ~/Documents/Teaching/UoNPhysicsCoding/demo_yr1/.venv/lib/python3.14/site-packages/jupyterquiz/dynamic/display.py:73, in display_quiz(ref, num, shuffle_questions, shuffle_answers, preserve_responses, border_radius, question_alignment, max_width, colors, load_js)
#      70     color_dict.update(colors)
#      72 # Build loading script
# ---> 73 prefix_script, static, url = load_questions_script(ref, div_id)
#      75 # Render HTML container and styles
#      76 mydiv = render_div(div_id, shuffle_questions, shuffle_answers,
#      77                    preserve_responses, num,
#      78                    max_width, border_radius, question_alignment)
#
# ...
